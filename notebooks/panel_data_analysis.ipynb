# %%
import pandas as pd

# %%
df_cities_static = pd.read_csv('../data/proc_data/cities_static.csv.zip', index_col=0)
df_cities_temp = pd.read_csv('../data/proc_data/cities_temp.csv.zip', parse_dates=[2], index_col=0)

# %%
df_cities_temp
# Out:
#           city_name city_code        date state  withdrawal  \
# 0            ABAÍRA   2900108  2020-04-13    BA       0.571
# 1            ABAÍRA   2900108  2020-04-14    BA       0.556
# 2            ABAÍRA   2900108  2020-04-15    BA       0.596
# 3            ABAÍRA   2900108  2020-04-16    BA       0.588
# 4            ABAÍRA   2900108  2020-04-17    BA       0.500
# ...             ...       ...         ...   ...         ...
# 164488  VOTUPORANGA   3557105  2021-02-22    SP       0.390
# 164489  VOTUPORANGA   3557105  2021-02-23    SP       0.390
# 164490  VOTUPORANGA   3557105  2021-02-24    SP       0.380
# 164491  VOTUPORANGA   3557105  2021-02-25    SP       0.400
# 164492  VOTUPORANGA   3557105  2021-02-26    SP       0.400
#
#         cable_tv_accesses  fixed_bandwidth_accesses  fixed_telephony_accesses  \
# 0                     979                       220                     735.0
# 1                     979                       220                     735.0
# ...
